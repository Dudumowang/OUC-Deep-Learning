# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=8, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def imshow(img):
    plt.figure(figsize=(8,8))
    img = img / 2 + 0.5     # 转换到 [0,1] 之间
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# 得到一组图像
images, labels = next(iter(trainloader))
# 展示图像
imshow(torchvision.utils.make_grid(images))
# 展示第一行图像的标签
for j in range(8):
    print(classes[labels[j]])
# Out:
# car
# deer
# dog
# plane
# dog
# bird
# cat
# deer

# %%
# 定义网络
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
# 网络训练
for epoch in range(10):
    for i, (inputs, labels) in enumerate(trainloader):
        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        if i % 100 == 0:
            print('Epoch: %d Minibatch: %5d loss: %.3f' %(epoch + 1, i + 1, loss.item()))
print('Finished Training')
# Out:
# Epoch: 1 Minibatch:     1 loss: 2.315
# Epoch: 1 Minibatch:   101 loss: 1.905
# Epoch: 1 Minibatch:   201 loss: 1.851
# Epoch: 1 Minibatch:   301 loss: 1.830
# Epoch: 1 Minibatch:   401 loss: 1.651
# Epoch: 1 Minibatch:   501 loss: 1.555
# Epoch: 1 Minibatch:   601 loss: 1.471
# Epoch: 1 Minibatch:   701 loss: 1.542
# Epoch: 2 Minibatch:     1 loss: 1.363
# Epoch: 2 Minibatch:   101 loss: 1.368
# Epoch: 2 Minibatch:   201 loss: 1.406
# Epoch: 2 Minibatch:   301 loss: 1.304
# Epoch: 2 Minibatch:   401 loss: 1.489
# Epoch: 2 Minibatch:   501 loss: 1.327
# Epoch: 2 Minibatch:   601 loss: 1.194
# Epoch: 2 Minibatch:   701 loss: 1.419
# Epoch: 3 Minibatch:     1 loss: 1.416
# Epoch: 3 Minibatch:   101 loss: 1.180
# Epoch: 3 Minibatch:   201 loss: 1.422
# Epoch: 3 Minibatch:   301 loss: 1.182
# Epoch: 3 Minibatch:   401 loss: 1.195
# Epoch: 3 Minibatch:   501 loss: 1.182
# Epoch: 3 Minibatch:   601 loss: 1.201
# Epoch: 3 Minibatch:   701 loss: 1.295
# Epoch: 4 Minibatch:     1 loss: 1.390
# Epoch: 4 Minibatch:   101 loss: 1.192
# Epoch: 4 Minibatch:   201 loss: 1.213
# Epoch: 4 Minibatch:   301 loss: 1.137
# Epoch: 4 Minibatch:   401 loss: 1.171
# Epoch: 4 Minibatch:   501 loss: 0.869
# Epoch: 4 Minibatch:   601 loss: 0.920
# Epoch: 4 Minibatch:   701 loss: 1.116
# Epoch: 5 Minibatch:     1 loss: 1.066
# Epoch: 5 Minibatch:   101 loss: 1.026
# Epoch: 5 Minibatch:   201 loss: 1.036
# Epoch: 5 Minibatch:   301 loss: 1.060
# Epoch: 5 Minibatch:   401 loss: 1.078
# Epoch: 5 Minibatch:   501 loss: 1.085
# Epoch: 5 Minibatch:   601 loss: 1.180
# Epoch: 5 Minibatch:   701 loss: 1.006
# Epoch: 6 Minibatch:     1 loss: 1.159
# Epoch: 6 Minibatch:   101 loss: 1.080
# Epoch: 6 Minibatch:   201 loss: 0.721
# Epoch: 6 Minibatch:   301 loss: 0.922
# Epoch: 6 Minibatch:   401 loss: 1.092
# Epoch: 6 Minibatch:   501 loss: 0.945
# Epoch: 6 Minibatch:   601 loss: 0.870
# Epoch: 6 Minibatch:   701 loss: 0.813
# Epoch: 7 Minibatch:     1 loss: 0.841
# Epoch: 7 Minibatch:   101 loss: 0.776
# Epoch: 7 Minibatch:   201 loss: 0.915
# Epoch: 7 Minibatch:   301 loss: 0.893
# Epoch: 7 Minibatch:   401 loss: 0.861
# Epoch: 7 Minibatch:   501 loss: 0.989
# Epoch: 7 Minibatch:   601 loss: 0.905
# Epoch: 7 Minibatch:   701 loss: 1.105
# Epoch: 8 Minibatch:     1 loss: 1.210
# Epoch: 8 Minibatch:   101 loss: 1.004
# Epoch: 8 Minibatch:   201 loss: 0.921
# Epoch: 8 Minibatch:   301 loss: 1.169
# Epoch: 8 Minibatch:   401 loss: 0.806
# Epoch: 8 Minibatch:   501 loss: 0.910
# Epoch: 8 Minibatch:   601 loss: 0.751
# Epoch: 8 Minibatch:   701 loss: 0.721
# Epoch: 9 Minibatch:     1 loss: 0.724
# Epoch: 9 Minibatch:   101 loss: 0.877
# Epoch: 9 Minibatch:   201 loss: 0.774
# Epoch: 9 Minibatch:   301 loss: 0.845
# Epoch: 9 Minibatch:   401 loss: 0.864
# Epoch: 9 Minibatch:   501 loss: 0.944
# Epoch: 9 Minibatch:   601 loss: 0.854
# Epoch: 9 Minibatch:   701 loss: 0.818
# Epoch: 10 Minibatch:     1 loss: 0.749
# Epoch: 10 Minibatch:   101 loss: 0.873
# Epoch: 10 Minibatch:   201 loss: 0.929
# Epoch: 10 Minibatch:   301 loss: 0.858
# Epoch: 10 Minibatch:   401 loss: 0.813
# Epoch: 10 Minibatch:   501 loss: 0.931
# Epoch: 10 Minibatch:   601 loss: 1.075
# Epoch: 10 Minibatch:   701 loss: 1.052
# Finished Training

# %%
# 得到一组图像
images, labels = next(iter(testloader))
# 展示图像
imshow(torchvision.utils.make_grid(images))
# 展示图像的标签
for j in range(8):
    print(classes[labels[j]])
# Out:
# cat
# ship
# ship
# plane
# frog
# frog
# car
# frog

# %%
outputs = net(images.to(device))
_, predicted = torch.max(outputs, 1)
# 展示预测的结果
for j in range(8):
    print(classes[predicted[j]])
# Out:
# cat
# plane
# ship
# plane
# cat
# frog
# car
# frog

# %%
correct = 0
total = 0

for data in testloader:
    images, labels = data
    images, labels = images.to(device), labels.to(device)
    outputs = net(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 63 %
